# %%
import pandas as pd

# %%
novalink_df = pd.read_csv('data/NovaLink_Telecom_Dirty_Exploration_Dataset.csv')

# %%
novalink_df.shape
# Out:
# (5000, 26)

# %%
novalink_df.head(2)
# Out:
#   customer_id subscription_id product_id   phone_number customer_name gender  \
# 0   CUST00001        SUB00001    PROD002  2348043756984    Customer 1   male
# 1   CUST00002        SUB00002    PROD004  2348095683063    Customer 2    NaN
#
#   age_group           city         region customer_segment  ... monthly_price  \
# 0     18-25           Kano     North West         premium   ...         12000
# 1     26-35  Port Harcourt  North Central              NaN  ...         35000
#
#   data_usage_mb voice_minutes sms_count monthly_bill payment_method  \
# 0          2146           NaN       233      12000.0            NaN
# 1           NaN        3162.0       291      35000.0           Card
#
#    network_type average_signal_strength_dbm  complaints_count  service_rating
# 0            4g                         NaN               NaN             5.0
# 1            3G                       -77.0               0.0             3.0
#
# [2 rows x 26 columns]

# %%
novalink_df.tail()
# Out:
#      customer_id subscription_id product_id   phone_number    customer_name  \
# 4995   CUST04996        SUB04996    PROD004  2348051843618    Customer 4996
# 4996   CUST04997        SUB04997    PROD003  2348038576108    Customer 4997
# 4997   CUST04998        SUB04998    PROD003  2348072642090    Customer 4998
# 4998   CUST04999        SUB04999    PROD003  2348029950713    Customer 4999
# 4999   CUST05000        SUB05000    PROD002  2348081318684   Customer 5000
#
#       gender age_group          city         region customer_segment  ...  \
# 4995    Male     18-25          Kano  North Central          Premium  ...
# 4996    male     36-45         lagos  North Central            Basic  ...
# 4997    Male     46-60        Ibadan     North West         Standard  ...
# 4998     NaN       NaN           NaN     North West         Standard  ...
# 4999  Female       60+  portharcourt     North West              NaN  ...
#
# ...

# %%
novalink_df.sample(5)
# Out:
#      customer_id subscription_id product_id   phone_number  customer_name  \
# 1376   CUST01377        SUB01377    PROD001  2348059955477  Customer 1377
# 1890   CUST01891        SUB01891    PROD001  2348081324025  Customer 1891
# 3606   CUST03607        SUB03607    PROD003  2348029097731  Customer 3607
# 2611   CUST02612        SUB02612    PROD005  2348094285415  Customer 2612
# 3110   CUST03111        SUB03111    PROD004  2348015918144  Customer 3111
#
#       gender age_group          city         region customer_segment  ...  \
# 1376       F       NaN          Kano  North Central         STANDARD  ...
# 1890  Female       NaN  portharcourt  North Central         STANDARD  ...
# 3606    Male     46-60        Ibadan    South South            Basic  ...
# 2611       M     26-35         lagos     South West        Corporate  ...
# 3110       M     26-35  portharcourt    South South         STANDARD  ...
#
#      monthly_price data_usage_mb voice_minutes sms_count monthly_bill  \
# ...

# %%
novalink_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   customer_id                  5000 non-null   str
#  1   subscription_id              5000 non-null   str
#  2   product_id                   5000 non-null   str
#  3   phone_number                 5000 non-null   int64
#  4   customer_name                5000 non-null   str
#  5   gender                       4548 non-null   str
#  6   age_group                    4148 non-null   str
#  7   city                         4551 non-null   str
#  8   region                       5000 non-null   str
#  9   customer_segment             4294 non-null   str
#  10  subscription_start_date      5000 non-null   str
#  11  subscription_status          4495 non-null   str
#  12  plan_type                    5000 non-null   str
# ...

# %%
novalink_df.columns
# Out:
# Index(['customer_id', 'subscription_id', 'product_id', 'phone_number',
#        'customer_name', 'gender', 'age_group', 'city', 'region',
#        'customer_segment', 'subscription_start_date', 'subscription_status',
#        'plan_type', 'contract_type', 'product_name', 'product_category',
#        'monthly_price', 'data_usage_mb', 'voice_minutes', 'sms_count',
#        'monthly_bill', 'payment_method', 'network_type',
#        'average_signal_strength_dbm', 'complaints_count', 'service_rating'],
#       dtype='str')
